# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import numpy as np

from sqlalchemy import create_engine
from sqlalchemy import types
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

import os
import sys
sys.path
sys.path.append('../')
from connections import password, client_id, client_secret

# %%
# Client credentials
client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id, 
    client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
cats = sp.categories()

# %%
cat_ids = []
for i in range(0, len(cats['categories']['items'])):
    cat_ids.append(cats['categories']['items'][i]['id'])

# %%
cat_playlists = []
for id in cat_ids:
    cat_playlists.append(sp.category_playlists(id))

# %%
cat_playlists
# Out:
# [{'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/toplists/playlists?offset=0&limit=20',
#    'items': [{'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXclgCwbk0uat'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXclgCwbk0uat',
#      'id': '37i9dQZF1DXclgCwbk0uat',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/25dd5a14aefecc7944b873059734da38fb875110',
#        'width': None}],
#      'name': 'Éxitos Chile',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTkwNjc0NiwwMDAwMDA4YjAwMDAwMTY5NTRkOWFlYjkwMDAwMDE2OGMzZjRmZmZi',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXclgCwbk0uat/tracks',
#       'total': 51},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DXclgCwbk0uat'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8O2z77nfMgH'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8O2z77nfMgH',
#      'id': '37i9dQZF1DX8O2z77nfMgH',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/d0bc7f6a8a43fe070af1c0a23994a6c46aa93379',
#        'width': None}],
#      'name': 'Novedades Viernes Sudamérica',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA1NTY4MiwwMDAwMDE0OTAwMDAwMTY5NWRiYTQ2ODcwMDAwMDE2OTU5NzdkZTQ0',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8O2z77nfMgH/tracks',
#       'total': 62},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX8O2z77nfMgH'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVxoleDT3ILq'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVxoleDT3ILq',
#      'id': '37i9dQZF1DWVxoleDT3ILq',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/45523c85ee11d3a442af801b2a11fc9b9834caf8',
#        'width': None}],
#      'name': 'Indie Chile',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTM2MzQ3MiwwMDAwMDA0NzAwMDAwMTY5MzQ3N2ZjOGQwMDAwMDE2ODkzZDNjODdj',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVxoleDT3ILq/tracks',
#       'total': 76},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWVxoleDT3ILq'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1QnNyJOBQBv'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1QnNyJOBQBv',
#      'id': '37i9dQZF1DX1QnNyJOBQBv',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/b91dd0cfd6492d7b69e3a102eb415aec6a69c1fd',
#        'width': None}],
#      'name': 'Latin Pop VIP',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjAyMTI2MCwwMDAwMDBhZTAwMDAwMTY5NWJhZDA3YzAwMDAwMDE2OTM5Y2I2NWI0',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1QnNyJOBQBv/tracks',
#       'total': 51},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3TKWnpd3vOb'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3TKWnpd3vOb',
#      'id': '37i9dQZF1DX3TKWnpd3vOb',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/e73d513f4fa4c6426025981fec2387181fbe4b33',
#        'width': None}],
#      'name': 'Rock Chileno',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc2MjIxMiwwMDAwMDAzYzAwMDAwMTY3YzdkYzliNmIwMDAwMDE2ODk5NmJlODM4',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3TKWnpd3vOb/tracks',
#       'total': 61},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX3TKWnpd3vOb'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXdxFkXW4j8RX'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdxFkXW4j8RX',
#      'id': '37i9dQZF1DXdxFkXW4j8RX',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/d31d2670c57c32a31138f79f0ff308a774ad0f98',
#        'width': None}],
#      'name': 'Rap Chileno',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc0OTkyNSwwMDAwMDAzODAwMDAwMTY3YzdkZDVlYWMwMDAwMDE2ODk4YjA2YWIw',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdxFkXW4j8RX/tracks',
#       'total': 60},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DXdxFkXW4j8RX'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5y71ufjoyXC'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5y71ufjoyXC',
#      'id': '37i9dQZF1DX5y71ufjoyXC',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/5ed79497c4011d19e95b5e733e5c1b2914f9fc1d',
#        'width': None}],
#      'name': 'Viral Latino',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA2OTUxNCwwMDAwMDA2MjAwMDAwMTY5NWU4ZDU0ZjMwMDAwMDE2OTU5NjZhYzJm',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5y71ufjoyXC/tracks',
#       'total': 27},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX5y71ufjoyXC'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWY7IeIP1cdjF'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWY7IeIP1cdjF',
#      'id': '37i9dQZF1DWY7IeIP1cdjF',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/1dc86d6013bd19b217aece92b783a9f2c799c0fe',
#        'width': None}],
#      'name': 'Baila Reggaeton',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA2NzI2OSwwMDAwMDBkZjAwMDAwMTY5NWU2YjE0MjIwMDAwMDE2OTJiOWNkOTNm',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWY7IeIP1cdjF/tracks',
#       'total': 51},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWY7IeIP1cdjF'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWU6aakG7fctq'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWU6aakG7fctq',
#      'id': '37i9dQZF1DWU6aakG7fctq',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/a61fe307872f9f0bc76766a7f7d4b0e58c5c3291',
#        'width': None}],
#      'name': 'Zona Indie',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjAyMTUzNCwwMDAwMDA4MDAwMDAwMTY5NWJiMTM4YzYwMDAwMDE2OTViNjljYWI4',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWU6aakG7fctq/tracks',
#       'total': 51},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWU6aakG7fctq'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX09mi3a4Zmox'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX09mi3a4Zmox',
#      'id': '37i9dQZF1DX09mi3a4Zmox',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/13cb3aa98a98f851ac041346a58b1c1906d0e33a',
#        'width': None}],
#      'name': 'Baladas Románticas',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NSwwMDAwMDA1MjAwMDAwMTY5NWU4ZTUxMzIwMDAwMDE2ODk4ZDg2YTI3',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX09mi3a4Zmox/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX09mi3a4Zmox'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbL0GavIqMTeb'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbL0GavIqMTeb',
#      'id': '37i9dQZEVXbL0GavIqMTeb',
#      'images': [{'height': None,
#        'url': 'https://charts-images.scdn.co/REGIONAL_CL_DEFAULT.jpg',
#        'width': None}],
#      'name': 'Chile Top 50',
#      'owner': {'display_name': 'spotifycharts',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotifycharts'},
#       'href': 'https://api.spotify.com/v1/users/spotifycharts',
#       'id': 'spotifycharts',
#       'type': 'user',
#       'uri': 'spotify:user:spotifycharts'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'NjA1MzgwNTg4LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbL0GavIqMTeb/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZEVXbL0GavIqMTeb'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF',
#      'id': '37i9dQZEVXbMDoHDwVN2tF',
#      'images': [{'height': None,
#        'url': 'https://charts-images.scdn.co/REGIONAL_GLOBAL_DEFAULT.jpg',
#        'width': None}],
#      'name': 'Global Top 50',
#      'owner': {'display_name': 'spotifycharts',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotifycharts'},
#       'href': 'https://api.spotify.com/v1/users/spotifycharts',
#       'id': 'spotifycharts',
#       'type': 'user',
#       'uri': 'spotify:user:spotifycharts'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'NjA1MzgwNTg3LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZEVXbMDoHDwVN2tF'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbLiRSasKsNU9'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbLiRSasKsNU9',
#      'id': '37i9dQZEVXbLiRSasKsNU9',
#      'images': [{'height': None,
#        'url': 'https://charts-images.scdn.co/VIRAL_GLOBAL_DEFAULT.jpg',
#        'width': None}],
#      'name': 'Global Viral 50',
#      'owner': {'display_name': 'spotifycharts',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotifycharts'},
#       'href': 'https://api.spotify.com/v1/users/spotifycharts',
#       'id': 'spotifycharts',
#       'type': 'user',
#       'uri': 'spotify:user:spotifycharts'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'NjA1MzA0ODg5LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbLiRSasKsNU9/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZEVXbLiRSasKsNU9'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbJs8e2vk15a8'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbJs8e2vk15a8',
#      'id': '37i9dQZEVXbJs8e2vk15a8',
#      'images': [{'height': None,
#        'url': 'https://charts-images.scdn.co/VIRAL_CL_DEFAULT.jpg',
#        'width': None}],
#      'name': 'Chile Viral 50',
#      'owner': {'display_name': 'spotifycharts',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotifycharts'},
#       'href': 'https://api.spotify.com/v1/users/spotifycharts',
#       'id': 'spotifycharts',
#       'type': 'user',
#       'uri': 'spotify:user:spotifycharts'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'NjA1MzA0ODg5LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbJs8e2vk15a8/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZEVXbJs8e2vk15a8'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX92MLsP3K1fI'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX92MLsP3K1fI',
#      'id': '37i9dQZF1DX92MLsP3K1fI',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/8a0a0d951a600f347336b7a0e7377264cb93a34c',
#        'width': None}],
#      'name': 'Pop Up',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTc1ODQ1MiwwMDAwMDBlZTAwMDAwMTY5NGMwMmU2YTMwMDAwMDE2OTM4MTY2MDEx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX92MLsP3K1fI/tracks',
#       'total': 139},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX92MLsP3K1fI'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6P1Nsk3wSZX'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6P1Nsk3wSZX',
#      'id': '37i9dQZF1DX6P1Nsk3wSZX',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/96002001fae3990e0616a8d18a42dcb2fd26e53f',
#        'width': None}],
#      'name': 'Hot Country - Top Tracks of 2018',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0NDcxMzY3NSwwMDAwMDAwMjAwMDAwMTY3YTgxYzIxNDMwMDAwMDE2N2E3ZjY4ZDdi',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6P1Nsk3wSZX/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX6P1Nsk3wSZX'}],
#    'limit': 20,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 16}},
#  {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/pop/playlists?offset=0&limit=20',
#    'items': [],
#    'limit': 20,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 0}},
#  {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/mood/playlists?offset=0&limit=20',
#    'items': [{'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWWMOmoXKqHTD'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWMOmoXKqHTD',
#      'id': '37i9dQZF1DWWMOmoXKqHTD',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/0a9bf517ddc5573fb660c98cc2a25181ad72957b',
#        'width': None}],
#      'name': 'Songs to Sing in the Car',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NywwMDAwMDAzYzAwMDAwMTY4NTZlOWVlMjMwMDAwMDE2NmYwOTU4NmQy',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWMOmoXKqHTD/tracks',
#       'total': 100},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWWMOmoXKqHTD'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXdPec7aLTmlC'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdPec7aLTmlC',
#      'id': '37i9dQZF1DXdPec7aLTmlC',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/e1f63e54458b1b237aff4b58bdd21d719cd309e3',
#        'width': None}],
#      'name': 'Happy Hits!',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NCwwMDAwMDA3OTAwMDAwMTY5NWNjNjAxMWIwMDAwMDE2ODk5YTA2ODUx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdPec7aLTmlC/tracks',
#       'total': 60},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DXdPec7aLTmlC'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSqmBTGDYngZ'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSqmBTGDYngZ',
#      'id': '37i9dQZF1DWSqmBTGDYngZ',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/3b7e8199da16b8d83cd2323a3abd8b700248aea8',
#        'width': None}],
#      'name': 'Songs to Sing in the Shower',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NCwwMDAwMDA4YjAwMDAwMTY4ZmY2MDM0OTQwMDAwMDE2ODk5YTBhMTFi',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSqmBTGDYngZ/tracks',
#       'total': 70},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWSqmBTGDYngZ'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3rxVfibe1L0'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3rxVfibe1L0',
#      'id': '37i9dQZF1DX3rxVfibe1L0',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/45e50c37774cd3e86f22985e24c0028a1d3a3b05',
#        'width': None}],
#      'name': 'Mood Booster',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0OCwwMDAwMDBiNzAwMDAwMTY4YjAzZWYyZGEwMDAwMDE2ODk5NzRhOWUy',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3rxVfibe1L0/tracks',
#       'total': 75},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX3rxVfibe1L0'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7KNKjOK0o75'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7KNKjOK0o75',
#      'id': '37i9dQZF1DX7KNKjOK0o75',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/954f97a75b44fb3e6ca974cd46eb58989f205a96',
#        'width': None}],
#      'name': 'Have a Great Day!',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk1MSwwMDAwMDA0NzAwMDAwMTY4NTZlOWVhMWIwMDAwMDE2ODk5YTI0Yzgy',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7KNKjOK0o75/tracks',
#       'total': 102},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX7KNKjOK0o75'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7gIoKXt0gmx'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7gIoKXt0gmx',
#      'id': '37i9dQZF1DX7gIoKXt0gmx',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/bc8ce7c568cc9d00efffce7b1489aa905fc6e439',
#        'width': None}],
#      'name': 'All The Feels',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0NDQ3MjI2NCwwMDAwMDA0MDAwMDAwMTY3OTliODgwOWMwMDAwMDE2NzM2MGZkYWVi',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7gIoKXt0gmx/tracks',
#       'total': 67},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX7gIoKXt0gmx'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4fpCWaHOned'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4fpCWaHOned',
#      'id': '37i9dQZF1DX4fpCWaHOned',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/954bb6a41ace7f997eb27748a0d7d2499428b430',
#        'width': None}],
#      'name': 'Confidence Boost',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NywwMDAwMDAzZDAwMDAwMTY5NTU5NWNlZTUwMDAwMDE2ODk5NzMzOGJm',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4fpCWaHOned/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX4fpCWaHOned'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6ziVCJnEm59'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6ziVCJnEm59',
#      'id': '37i9dQZF1DX6ziVCJnEm59',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/08eaf527cfb7211b86b726936a34f7670fb02099',
#        'width': None}],
#      'name': 'Your Favorite Coffeehouse',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTQ1NTY1NCwwMDAwMDA2MzAwMDAwMTY5MzlmNjkyMWYwMDAwMDE2ODk5OWQ1ZTc3',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6ziVCJnEm59/tracks',
#       'total': 105},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX6ziVCJnEm59'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSXBu5naYCM9'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXBu5naYCM9',
#      'id': '37i9dQZF1DWSXBu5naYCM9',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/6454993b76a659c3658f8f1741e2b5a9d332225f',
#        'width': None}],
#      'name': 'A Perfect Day',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTgwMzAwNSwwMDAwMDA2NzAwMDAwMTY5NGVhYWI5YjkwMDAwMDE2ODk4YmRhZmUx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXBu5naYCM9/tracks',
#       'total': 80},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWSXBu5naYCM9'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWWjGdmeTyeJ6'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWjGdmeTyeJ6',
#      'id': '37i9dQZF1DWWjGdmeTyeJ6',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/fdfd26bf0d5c544260c5bfe7c2a278693a0d82fd',
#        'width': None}],
#      'name': 'Fresh Finds',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTg4NzE1OCwwMDAwMDA5OTAwMDAwMTY5NTNhZWNlYzgwMDAwMDE2OTUzYWUwZmI5',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWjGdmeTyeJ6/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWWjGdmeTyeJ6'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0UrRvztWcAU'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0UrRvztWcAU',
#      'id': '37i9dQZF1DX0UrRvztWcAU',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/237dbe5ad6d3e8a60b0d79d5a6303cc531b56440',
#        'width': None}],
#      'name': 'Wake Up Happy',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NiwwMDAwMDA4YjAwMDAwMTY5NWMxZmY2YTUwMDAwMDE2ODk1NGE3ZDc0',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0UrRvztWcAU/tracks',
#       'total': 70},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX0UrRvztWcAU'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWWBHeXOYZf74'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWBHeXOYZf74',
#      'id': '37i9dQZF1DWWBHeXOYZf74',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/cd2060615e82dac24b3b45785a302a8e36eaee6d',
#        'width': None}],
#      'name': 'POLLEN',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA2NDIyNSwwMDAwMDA5YjAwMDAwMTY5NWUzY2EyNDIwMDAwMDE2OTVhMzFkMWEx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWBHeXOYZf74/tracks',
#       'total': 100},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWWBHeXOYZf74'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX3YSRoSdA634'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3YSRoSdA634',
#      'id': '37i9dQZF1DX3YSRoSdA634',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/372d9f2e19a42ce2b12cc33f748cfb7c1a7517e5',
#        'width': None}],
#      'name': 'Life Sucks',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0OCwwMDAwMDA0YzAwMDAwMTY4ZTE2Y2YzNGUwMDAwMDE2ODk4YmNkOTYy',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX3YSRoSdA634/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX3YSRoSdA634'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1tyCD9QhIWF'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1tyCD9QhIWF',
#      'id': '37i9dQZF1DX1tyCD9QhIWF',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/9f23b652c0436bf56fd8f828ed379aa5f40ea1a0',
#        'width': None}],
#      'name': 'Walk Like A Badass',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0OTkwNDUxOCwwMDAwMDA1NzAwMDAwMTY4ZGQ4MjFjYzcwMDAwMDE2ODk4Y2VkODc4',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1tyCD9QhIWF/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX1tyCD9QhIWF'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9XIFQuFvzM4'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9XIFQuFvzM4',
#      'id': '37i9dQZF1DX9XIFQuFvzM4',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/489c047090d5691837316bf5ca282e408ce9886f',
#        'width': None}],
#      'name': "Feelin' Good",
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NywwMDAwMDAyYzAwMDAwMTY4NTZlOWRmOGUwMDAwMDE2ODk5YTEzOWI3',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9XIFQuFvzM4/tracks',
#       'total': 100},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX9XIFQuFvzM4'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXmlLSKkfdAk'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXmlLSKkfdAk',
#      'id': '37i9dQZF1DWXmlLSKkfdAk',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/1ab6c49c810a7649aa9016c0dccf2bba2fbeb802',
#        'width': None}],
#      'name': 'Acoustic Covers',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTQ1NTAzNiwwMDAwMDA0ZTAwMDAwMTY5MzllZDI1OGMwMDAwMDE2ODk4YzUxNzlh',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXmlLSKkfdAk/tracks',
#       'total': 116},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWXmlLSKkfdAk'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6Rl8uES4jYu'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6Rl8uES4jYu',
#      'id': '37i9dQZF1DX6Rl8uES4jYu',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/d266e93287a1f8cf574c8f996b2ee3a85d6b1785',
#        'width': None}],
#      'name': 'Ready for the Day',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3NDcyMSwwMDAwMDAyZDAwMDAwMTY5NWVkY2NhNTQwMDAwMDE2N2M3ZjA4NDU0',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6Rl8uES4jYu/tracks',
#       'total': 72},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX6Rl8uES4jYu'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYiR2Uqcon0X'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYiR2Uqcon0X',
#      'id': '37i9dQZF1DWYiR2Uqcon0X',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/d83e8fcdef35560f1f1ae24122c8b4f5c90520d0',
#        'width': None}],
#      'name': 'Country Coffeehouse',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTE5OTU5MiwwMDAwMDAzMzAwMDAwMTY5MmFiMzVmNWYwMDAwMDE2ODk4ZTEyOTMw',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYiR2Uqcon0X/tracks',
#       'total': 54},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWYiR2Uqcon0X'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6xZZEgC9Ubl'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6xZZEgC9Ubl',
#      'id': '37i9dQZF1DX6xZZEgC9Ubl',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/b160ab2b7110c8d700fab792e372de78efe4be1b',
#        'width': None}],
#      'name': 'Tear Drop',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1MzA3OSwwMDAwMDA0NTAwMDAwMTY3OTkzOWVkYTkwMDAwMDE2ODk4ZTA4YjNj',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6xZZEgC9Ubl/tracks',
#       'total': 54},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX6xZZEgC9Ubl'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYBO1MoTDhZI'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYBO1MoTDhZI',
#      'id': '37i9dQZF1DWYBO1MoTDhZI',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/109b80c1fa65b42ec86e6cf030be0f4cf24a6d46',
#        'width': None}],
#      'name': 'Good Vibes',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1MTA2MiwwMDAwMDA2NzAwMDAwMTY3N2I1OTJlNGMwMDAwMDE2ODk4YzFjNGE0',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYBO1MoTDhZI/tracks',
#       'total': 82},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWYBO1MoTDhZI'}],
#    'limit': 20,
#    'next': 'https://api.spotify.com/v1/browse/categories/mood/playlists?offset=20&limit=20',
#    'offset': 0,
#    'previous': None,
#    'total': 96}},
#  {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/edm_dance/playlists?offset=0&limit=20',
#    'items': [{'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4dyzvuaRJ0n'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4dyzvuaRJ0n',
#      'id': '37i9dQZF1DX4dyzvuaRJ0n',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/dada7eb6a7c14b002b2e45f58c13fa2ccf95ec28',
#        'width': None}],
#      'name': 'mint',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjAyMTI2MCwwMDAwMDM2MjAwMDAwMTY5NWJhZDA3YjQwMDAwMDE2OTU5MzAyMDZh',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4dyzvuaRJ0n/tracks',
#       'total': 54},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX4dyzvuaRJ0n'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8tZsk68tuDw'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8tZsk68tuDw',
#      'id': '37i9dQZF1DX8tZsk68tuDw',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/d1bc06ca84bc17dd8d00b32f1e9a1170194cc4b0',
#        'width': None}],
#      'name': 'Dance Rising',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjAyMTI2MCwwMDAwMDJjYjAwMDAwMTY5NWJhZDA3YzYwMDAwMDE2OTM1OGI3ZjA3',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8tZsk68tuDw/tracks',
#       'total': 96},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX8tZsk68tuDw'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX2VvACCrgjrt'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2VvACCrgjrt',
#      'id': '37i9dQZF1DX2VvACCrgjrt',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/ea52dd3caff0cb150a7706f0985f09747f72ec23',
#        'width': None}],
#      'name': 'Nasty Bits',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjAyMTI2MCwwMDAwMDAyODAwMDAwMTY5NWJhZDA4OTgwMDAwMDE2OTQ5ZGI4OTAx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2VvACCrgjrt/tracks',
#       'total': 73},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX2VvACCrgjrt'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaXB8fQg7xif'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaXB8fQg7xif',
#      'id': '37i9dQZF1DXaXB8fQg7xif',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/887b341f19608d3949491c6ee8f920cd0868437c',
#        'width': None}],
#      'name': 'Dance Party',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NywwMDAwMDBkZDAwMDAwMTY5NWJhZDA4MjQwMDAwMDE2OTUwZDMyNTY5',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaXB8fQg7xif/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DXaXB8fQg7xif'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6VdMW310YC7'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6VdMW310YC7',
#      'id': '37i9dQZF1DX6VdMW310YC7',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/bb3e01dc5fda482f2000590b525c03cda4b50d52',
#        'width': None}],
#      'name': 'Chill Tracks',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NywwMDAwMDBmZTAwMDAwMTY4YTg1YWVhNDcwMDAwMDE2NmQxZTQ5MTkx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6VdMW310YC7/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX6VdMW310YC7'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8a1tdzq5tbM'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8a1tdzq5tbM',
#      'id': '37i9dQZF1DX8a1tdzq5tbM',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/52254e29d2c764f45be4d9e01cf58fa740590d8c',
#        'width': None}],
#      'name': 'Dance Classics',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0NywwMDAwMDAxZjAwMDAwMTY3YTNiYjU2NTYwMDAwMDE2ODk5YTNmZThk',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8a1tdzq5tbM/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX8a1tdzq5tbM'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6GJXiuZRisr'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6GJXiuZRisr',
#      'id': '37i9dQZF1DX6GJXiuZRisr',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/f7311ed03b58d69256b300c2718dfcbd05784be4',
#        'width': None}],
#      'name': 'Night Rider',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTgwODQwMywwMDAwMDA3NDAwMDAwMTY5NGVmZDE5ZGYwMDAwMDE2OGNjNGZiZGZh',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6GJXiuZRisr/tracks',
#       'total': 55},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX6GJXiuZRisr'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX91oIci4su1D'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX91oIci4su1D',
#      'id': '37i9dQZF1DX91oIci4su1D',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/54f721790b6abf39168facd8ca2c326b852596bf',
#        'width': None}],
#      'name': 'Trance Mission',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0OSwwMDAwMDA1NjAwMDAwMTY5M2ExZDk4MzQwMDAwMDE2OGNjMmMxYzcy',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX91oIci4su1D/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX91oIci4su1D'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9cbNxuNYT3d'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9cbNxuNYT3d',
#      'id': '37i9dQZF1DX9cbNxuNYT3d',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/f7c8e1a352cd117707494e4c7c6d77c48fefb139',
#        'width': None}],
#      'name': 'French Touch All-Star',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0NTgxNDc1NCwwMDAwMDAyZDAwMDAwMTY3ZTliZDQ2OGUwMDAwMDE2N2U5YmJmMDQw',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9cbNxuNYT3d/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX9cbNxuNYT3d'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTU3Zl0elDUa'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTU3Zl0elDUa',
#      'id': '37i9dQZF1DWTU3Zl0elDUa',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/718ac2fb8cb2dcddcef8c05d5f59124838a882ce',
#        'width': None}],
#      'name': '90s House Classics',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MjA3ODk0MCwwMDAwMDAwNTAwMDAwMTY4NWM1YzM3OTUwMDAwMDE2ODRkMDc3MDAy',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTU3Zl0elDUa/tracks',
#       'total': 60},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWTU3Zl0elDUa'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8CopunbDxgW'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8CopunbDxgW',
#      'id': '37i9dQZF1DX8CopunbDxgW',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/261d86371cbabd1fd9781b2af91b1097f124d23d',
#        'width': None}],
# ...
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTcwODU0NCwwMDAwMDAwYTAwMDAwMTY5NDkwOTVjMjAwMDAwMDE2NzJjYWY1ZTQ0',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZYpU3rwrcAz/tracks',
#       'total': 49},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWZYpU3rwrcAz'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWV0gynK7G6pD'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV0gynK7G6pD',
#      'id': '37i9dQZF1DWV0gynK7G6pD',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/39f0f454766c7b03cf1f5e572b17e029dc0e467b',
#        'width': None}],
#      'name': 'Classical New Releases: Spotify Picks',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU1MTQ0NjkzNCwwMDAwMDBjZjAwMDAwMTY5Mzk3MTg1ZDQwMDAwMDE2ODkzYzdkOTBm',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV0gynK7G6pD/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWV0gynK7G6pD'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9G9wwzwWL2k'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9G9wwzwWL2k',
#      'id': '37i9dQZF1DX9G9wwzwWL2k',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/61a6e1800b4e1c4dee0e44cd00ec86e2027479e3',
#        'width': None}],
#      'name': 'Epic Classical',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1Mjc2NCwwMDAwMDAyMjAwMDAwMTYxNmI0YmVlNTgwMDAwMDE2ODk4ZGJiZTZm',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9G9wwzwWL2k/tracks',
#       'total': 100},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX9G9wwzwWL2k'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6K3W8KBiALe'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6K3W8KBiALe',
#      'id': '37i9dQZF1DX6K3W8KBiALe',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/20d4b8d542a76f80d04ff02b5fe8695f0753bcd7',
#        'width': None}],
#      'name': 'Classical Moments in Movies',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1MDg4OCwwMDAwMDAwODAwMDAwMTVkYzcyNTdmYjgwMDAwMDE2ODk4YmYxY2Rm',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6K3W8KBiALe/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX6K3W8KBiALe'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXah8e1pvF5oE'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXah8e1pvF5oE',
#      'id': '37i9dQZF1DXah8e1pvF5oE',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/6990f2c5870f5cb7bd33c685bf98a287d09632a4',
#        'width': None}],
#      'name': 'Piano 100: Spotify Picks',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODY5MjkxMywwMDAwMDAxMDAwMDAwMTYxNjYzY2Q0ZWQwMDAwMDE2ODk1NGE3ZTkz',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXah8e1pvF5oE/tracks',
#       'total': 100},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DXah8e1pvF5oE'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX2mmt7R81K2b'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2mmt7R81K2b',
#      'id': '37i9dQZF1DX2mmt7R81K2b',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/8aada948b18c4a1e66d231d496cd7fd7d5a642e0',
#        'width': None}],
#      'name': 'Jazz – Classical Crossings',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc2MjgxNCwwMDAwMDAxYzAwMDAwMTY0MDI4ZTdkYzgwMDAwMDE2ODk5NzUxOTRi',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX2mmt7R81K2b/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX2mmt7R81K2b'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX561TxkFttR4'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX561TxkFttR4',
#      'id': '37i9dQZF1DX561TxkFttR4',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/814e37aba2ccf8b580a149e115559fe73838dca0',
#        'width': None}],
#      'name': '88 Keys',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1MjE4MSwwMDAwMDAxYjAwMDAwMTY1MjNmNDBkNWQwMDAwMDE2ODk4ZDJkNzgx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX561TxkFttR4/tracks',
#       'total': 88},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX561TxkFttR4'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWUqIzZNMSCv3'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUqIzZNMSCv3',
#      'id': '37i9dQZF1DWUqIzZNMSCv3',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/b41c71e276d101b9ad3b2af58355141edd43ee91',
#        'width': None}],
#      'name': 'Gentle Piano Concertos',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1MjExMiwwMDAwMDAwYzAwMDAwMTVmMzNkMzAyMzUwMDAwMDE2ODk4ZDFjYTAz',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUqIzZNMSCv3/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWUqIzZNMSCv3'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7cBprxbt1Fn'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7cBprxbt1Fn',
#      'id': '37i9dQZF1DX7cBprxbt1Fn',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/51da7e74d5a0cb46c1b95a2eeb01d039e8ceddf3',
#        'width': None}],
#      'name': 'Gentle Classical: From Dusk till Dawn',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1MjY5OCwwMDAwMDAyYTAwMDAwMTY1OGFlNzQ0NTYwMDAwMDE2ODk4ZGFiZTU5',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7cBprxbt1Fn/tracks',
#       'total': 101},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX7cBprxbt1Fn'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX99gNWyxQ2OR'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX99gNWyxQ2OR',
#      'id': '37i9dQZF1DX99gNWyxQ2OR',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/318b739c882298e8e86161b451e3fdd0c72593ea',
#        'width': None}],
#      'name': 'Chopin Nocturnes',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0MjYzODQ0NiwwMDAwMDAwMjAwMDAwMTY3MmM2YWE4ZDkwMDAwMDE2NzJjNjU3MmU4',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX99gNWyxQ2OR/tracks',
#       'total': 21},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX99gNWyxQ2OR'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVfS4Cdd3PNf'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVfS4Cdd3PNf',
#      'id': '37i9dQZF1DWVfS4Cdd3PNf',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/53b420d7df9bfaf4d5926610533e8200014f806e',
#        'width': None}],
#      'name': 'Opera 100: Spotify Picks',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1Mjc2NCwwMDAwMDAxYjAwMDAwMTVlNjBhM2RkOGYwMDAwMDE2ODk4ZGJiZDg5',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVfS4Cdd3PNf/tracks',
#       'total': 100},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWVfS4Cdd3PNf'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXabrEiRjQMgs'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXabrEiRjQMgs',
#      'id': '37i9dQZF1DXabrEiRjQMgs',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/e5c1adc0ed70dec13c9d3877176a0d1fc11baaa4',
#        'width': None}],
#      'name': 'Classical Dance Music: Ballet & Beyond',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc2MjQyNSwwMDAwMDAxYjAwMDAwMTVkYzZlODM5ZDcwMDAwMDE2ODk5NmYyN2Y3',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXabrEiRjQMgs/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DXabrEiRjQMgs'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXddGd6mP5X2a'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXddGd6mP5X2a',
#      'id': '37i9dQZF1DXddGd6mP5X2a',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/deebd24765522f6179be8326e208fb9b21a71046',
#        'width': None}],
#      'name': 'Orchestra 100: Spotify Picks',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODY2NzU3NiwwMDAwMDAwNzAwMDAwMTVjZjdiNzgyMzkwMDAwMDE2ODkzYzdlMGFm',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXddGd6mP5X2a/tracks',
#       'total': 100},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DXddGd6mP5X2a'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXBq4mDDFnfA'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXBq4mDDFnfA',
#      'id': '37i9dQZF1DWXBq4mDDFnfA',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/ad99503c408279f2c117b658c19e5df0e35f2a00',
#        'width': None}],
#      'name': 'Classical Guitar 50: Spotify Picks',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1Mjk4MiwwMDAwMDAwYTAwMDAwMTYwNGFlNDk2NDAwMDAwMDE2ODk4ZGYxMjAx',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXBq4mDDFnfA/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWXBq4mDDFnfA'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX10uaP8FoDNe'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX10uaP8FoDNe',
#      'id': '37i9dQZF1DX10uaP8FoDNe',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/4fca5150069ae26e03b39abc2bd2f545bcfdd5eb',
#        'width': None}],
#      'name': 'Minimalism',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODY5Mjg4NiwwMDAwMDAwYjAwMDAwMTYyZTIyNzgwM2EwMDAwMDE2ODk1NGExMjg5',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX10uaP8FoDNe/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DX10uaP8FoDNe'},
#     {'collaborative': False,
#      'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYi4w24l7FTx'},
#      'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYi4w24l7FTx',
#      'id': '37i9dQZF1DWYi4w24l7FTx',
#      'images': [{'height': None,
#        'url': 'https://pl.scdn.co/images/pl/default/8c647e6c9d3218240da3adcde1d6be18e80b8d55',
#        'width': None}],
#      'name': 'Spotify Orchestra: Cello',
#      'owner': {'display_name': 'Spotify',
#       'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#       'href': 'https://api.spotify.com/v1/users/spotify',
#       'id': 'spotify',
#       'type': 'user',
#       'uri': 'spotify:user:spotify'},
#      'primary_color': None,
#      'public': None,
#      'snapshot_id': 'MTU0ODc1MDkxNSwwMDAwMDAyMzAwMDAwMTYxYjU0ZDU3OTAwMDAwMDE2ODk4YmY4N2Uz',
#      'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYi4w24l7FTx/tracks',
#       'total': 50},
#      'type': 'playlist',
#      'uri': 'spotify:playlist:37i9dQZF1DWYi4w24l7FTx'}],
#    'limit': 20,
#    'next': 'https://api.spotify.com/v1/browse/categories/classical/playlists?offset=20&limit=20',
#    'offset': 0,
#    'previous': None,
#    'total': 51}}]
